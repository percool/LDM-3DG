# %%
import numpy as np
loss=[123.538045,
0.802045,
0.713945,
0.653651,
0.606030,
0.559145,
0.509201,
0.452887,
0.391927,
0.334024,
0.284986,
0.247772,
0.218922,
0.196326,
0.174732,
0.158733,
0.143584,
0.130051,
0.115592,
0.102762,
0.092958,
0.084468,
0.076778,
0.096571,
0.065085,
0.066555,
0.068388,
0.065284]
loss=np.array(loss)
iters=np.arange(1,len(loss)+1)*1000

# %%
import matplotlib.pyplot as plt


# Create a line plot
plt.semilogy(iters, loss,'.')

# Add labels and title
plt.xlabel("iters")
plt.ylabel("loss")
plt.title("Diffusion Model Loss")

# Display the plot
plt.show()
